# %% [markdown]
# 1. Project Overview
#
# Customer support teams receive a large number of requests every day through emails, forms, or support portals. These requests must be manually reviewed, categorized, and prioritized before being assigned to the appropriate team.
#
# Manual processing slows down response times and increases operational workload.
#
# This project demonstrates how internal support processes can be automated using workflow automation and data analytics tools. The system automatically processes support tickets, categorizes them, assigns priorities, and provides analytics dashboards for monitoring trends.
#
# The automation workflow is implemented using n8n and the analytics dashboard is built using Microsoft Power BI.

# %% [markdown]
# 2. Problem Statement
#
# Organizations often receive a high volume of customer support tickets that require manual processing.
#
# Typical manual workflow:
#
# Support agent reads incoming ticket
#
# Agent determines the issue category
#
# Agent assigns priority level
#
# Ticket is logged into a system
#
# Management tracks statistics manually
#
# This process is:
#
# time consuming
#
# repetitive
#
# prone to human error
#
# An automated system can reduce manual effort and provide real-time insights into ticket patterns and response priorities.
#
# 3. Proposed Solution
#
# The proposed system automates the processing of support tickets through a workflow pipeline.
#
# The system will:
#
# Collect support tickets in a dataset
#
# Trigger an automation workflow when a new ticket appears
#
# Automatically classify the ticket category
#
# Assign a priority level
#
# Store structured data for analysis
#
# Generate dashboards to visualize trends and operational metrics
#
# This approach demonstrates how automation tools can improve internal processes and decision-making.

# %% [markdown]
# 4. System Architecture
# Email / Form Submission
#         ↓
# Automation Workflow (n8n)
#         ↓
# AI Classifies Ticket
#         ↓
# Database / Spreadsheet
#         ↓
# Power BI Dashboard

# %% [markdown]
# 5. Dataset Design
#
# How the Dataset Was Created
#
# The dataset was manually generated to represent realistic support scenarios. Example tickets include:
#
# login issues
#
# payment failures
#
# system bugs
#
# feature requests
#
# Initially, the Category and Priority fields were left empty. These fields will later be automatically populated by the automation workflow implemented using n8n.
#
# The processed dataset will then be used to generate analytics dashboards in Microsoft Power BI to visualize ticket trends and operational insights.
#
# Dataset Structure
#
# The dataset contains the following columns:
#
# Column	Description
# Ticket_ID	A unique identifier assigned to each ticket
# Subject	A short title describing the issue
# Message	A more detailed description of the problem
# Category	The type of issue (this field will be filled automatically later)
# Priority	The urgency level of the ticket (also assigned automatically later)
# Date	The date when the ticket was created

# %% [markdown]
# n8n
#
# An automation workflow was implemented using n8n to process
# incoming support tickets.
#
# The workflow reads ticket data from a dataset and applies
# classification logic to determine the category and priority
# of each ticket.
#
# The processed data is then stored for further analysis.
#
# Explanation of Nodes added  :
#
# Manual Trigger: Starts the workflow manually.
#
# Read CSV Dataset: Reads the raw ticket data from a CSV file containing ticket details.
#
# Code Node: Processes each ticket to assign a category and priority based on keywords.
#
# Write Processed Dataset: Outputs a new CSV file ready for analytics.
#
# CODE NODE (Classify Tickets)
#
# Purpose: Automatically categorize tickets and assign priority.
#
# Configuration: JavaScript code:

# %%
return items.map(item => {

  // Combine subject and message safely
  const subject = item.json.Subject ? item.json.Subject.toLowerCase() : "";
  const message = item.json.Message ? item.json.Message.toLowerCase() : "";
  const text = subject + " " + message;

  let category = "General";
  let priority = "Low";

  // Technical issues
  if (text.includes("login") || text.includes("password") || text.includes("account")) {
    category = "Technical";
    priority = "High";
  }

  // Billing issues
  else if (text.includes("payment") || text.includes("refund") || text.includes("billing")) {
    category = "Billing";
    priority = "Medium";
  }

  // Product requests
  else if (text.includes("feature") || text.includes("request") || text.includes("add")) {
    category = "Product";
    priority = "Low";
  }

  // Write results to sheet columns
  item.json.Category = category;
  item.json.Priority = priority;

  return item;
});

# %% [markdown]
# Observation:
#
# Tickets containing “login” or “password” are classified as Technical, High priority.
#
# Tickets containing “payment” or “refund” are Billing, Medium priority.
#
# Tickets containing “feature” or “request” are Product, Low priority.
#
# Default category and priority are General, Low.
#
# Screenshots / Evidence
#
# (Add screenshots of n8n workflow canvas, showing each node connected and configured.)

# %% [markdown]
# Analytics Dashboard Development
# 1. Objective
#
# The objective of this task was to build a ticket analytics dashboard using Microsoft Power BI Desktop.
# The dashboard visualizes support ticket data to simulate how companies monitor customer issues, priorities, and operational performance.
#
# The dashboard helps identify:
#
# the distribution of support tickets across categories
#
# the urgency of incoming tickets
#
# trends in ticket volume over time
#
# response priority distribution
#
# This type of dashboard is commonly used by customer support teams, product teams, and operations managers to monitor system issues and service performance.

# %% [markdown]
# Data Import Process
#
# The dataset was imported into Microsoft Power BI Desktop using the Get Data functionality.
#
# Steps performed:
#
# Open Power BI Desktop.
#
# Select Home → Get Data.
#
# Import the dataset file (CSV or Excel).
#
# Data is loaded into the Power Query Editor.
#
# Column types were verified:
#
# Ticket_ID → Numeric
#
# Category → Text
#
# Priority → Text
#
# Date → Date format
#
# After verifying the data, the Create Report option was selected to begin building the dashboard.

# %% [markdown]
# Dashboard Visualizations
#
# Three main visualizations were created to analyze the support ticket data.
#
#  Tickets by Category
#
# Visualization type: Column Chart
#
# This chart shows the number of support tickets grouped by category.
#
# Categories included:
#
# Technical
#
# Billing
#
# Product
#
# General
#
# Purpose:
# This visualization helps identify which areas of the system generate the most support requests. For example, a high number of technical tickets may indicate system bugs or infrastructure issues.
#
#  Tickets by Priority
#
# Visualization type: Column Chart
#
# This chart displays the number of tickets based on urgency level.
#
# Priority levels:
#
# High
#
# Medium
#
# Low
#
# Purpose:
# This chart helps support teams understand the urgency distribution of incoming tickets and prioritize resources accordingly.
#
#  Tickets Over Time
#
# Visualization type: Line Chart
#
# This chart visualizes ticket creation over time.
#
# Example pattern:
#
# March 1 → multiple tickets created
#
# March 2 → increased ticket volume
#
# March 3 → moderate ticket activity
#
# Purpose:
# This visualization helps detect trends or spikes in ticket volume which could indicate system outages, bugs, or product updates causing issues.
